# %%
import pandas as pd
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df = pd.read_pickle('event.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333980 entries, 0 to 3333979
# Data columns (total 19 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   report_number              int64
#  1   date_reported              object
#  2   date_occurred              object
#  3   time_occurred              object
#  4   area_code                  category
#  5   report_district_number     int64
#  6   crime_part                 bool
#  7   crime_codes                category
#  8   mocodes                    category
#  9   victim_age                 uint8
#  10  victim_sex                 bool
#  11  victim_descent             category
#  12  premises_code              category
#  13  weapon_code                category
#  14  status_code                category
#  15  number_of_crimes           uint8
#  16  is_victim_descent_missing  bool
#  17  is_victim_sex_missing      bool
#  18  is_victim_age_missing      bool
# dtypes: bool(5), category(7), int64(2), object(3), uint8(2)
# memory usage: 181.2+ MB

# %%
df.date_reported = pd.to_datetime(df.date_reported)
df.time_occurred = pd.to_datetime(df.time_occurred)

# %%
df_filtered = df.drop_duplicates(subset='report_number').drop(columns='report_number')
df_filtered
# Out:
#         date_reported date_occurred time_occurred area_code  \
# 0          2020-02-09    2020-02-08         18:00         1
# 6          2020-11-11    2020-11-04         17:00         3
# 8          2023-05-10    2020-03-10         20:37         9
# 10         2020-07-07    2020-07-07         13:40         2
# 18         2020-03-02    2020-03-01         14:30         4
# ...               ...           ...           ...       ...
# 3333966    2025-01-25    2025-01-24         12:40        10
# 3333969    2025-01-17    2025-01-17         16:00        17
# 3333973    2025-02-02    2025-01-30         17:30        11
# 3333976    2025-01-19    2025-01-17         15:30        21
# 3333977    2025-01-14    2025-01-14         12:50         5
#
#          report_district_number  crime_part crime_codes mocodes  victim_age  \
# 0                           182        True       330.0    1822          47
# 6                           356        True       480.0    0344          19
# 8                           964        True       343.0    0325          19
# 10                          265        True       648.0    0329          30
# 18                          407        True       310.0    0344          27
# ...                         ...         ...         ...     ...         ...
# 3333966                    1008        True       331.0    1822          68
# 3333969                    1774       False       624.0    0400          17
# 3333973                    1101        True       330.0    0344          32
# 3333976                    2114        True       341.0    0344          40
# 3333977                     509        True       210.0    1822          15
#
#          victim_sex victim_descent premises_code weapon_code status_code  \
# 0              True              O         128.0         0.0          IC
# 6              True              X         502.0         0.0          IC
# 8              True              O         405.0         0.0          IC
# 10            False              X         101.0         0.0          IC
# 18             True              W         221.0         0.0          IC
# ...             ...            ...           ...         ...         ...
# 3333966        True              O         108.0         0.0          IC
# 3333969        True              H         721.0       400.0          IC
# 3333973       False              H         109.0         0.0          IC
# 3333976        True              W         720.0         0.0          IC
# 3333977       False              H         721.0       400.0          IC
#
#          number_of_crimes  is_victim_descent_missing  is_victim_sex_missing  \
# 0                       2                      False                  False
# 6                       1                      False                   True
# 8                       1                      False                  False
# 10                      2                      False                   True
# 18                      1                      False                  False
# ...                   ...                        ...                    ...
# 3333966                 1                      False                  False
# 3333969                 1                      False                  False
# 3333973                 1                      False                  False
# 3333976                 1                      False                  False
# 3333977                 1                      False                  False
#
#          is_victim_age_missing
# 0                        False
# 6                        False
# 8                        False
# 10                        True
# 18                       False
# ...                        ...
# 3333966                  False
# 3333969                  False
# 3333973                  False
# 3333976                   True
# 3333977                  False
#
# [853344 rows x 18 columns]
